# %%
import pickle
import os
import glob
from tqdm import tqdm
import numpy as np

# %%
# for i in tqdm(glob.glob("/mimer/NOBACKUP/groups/snic2022-6-127/PPI_prediction/pickle/not*18*")):
#     name = i.split("/")[-1]
#     new_dct = {}
#     print(name)
# # try:
#     with open(i, 'rb') as handle:
#         dc= pickle.load(handle)
#     for i,j in dc.items():
#         new_dct[i] = np.sum(j[1:],axis = 0)
#     dc = {}
#     with open(f'/cephyr/NOBACKUP/groups/snic2019-35-21/PPI/sum_pickle_not_mean/{name}', 'wb') as handle:
#         pickle.dump(new_dct, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
            
# #     except:
#         print("Error")

# %%
# with open('/mimer/NOBACKUP/groups/snic2022-6-127/PPI_prediction/pickle/not_mean_embedded_vectors_bert_bfd_combined_27.pickle', 'rb') as handle:
    
#     dc= pickle.load(handle)

# %%
for i in tqdm(glob.glob("/mimer/NOBACKUP/groups/snic2022-6-127/PPI_prediction/pickle/not*2*")):
    name = i.split("/")[-1]
    new_dct = {}
    print(name)
# try:
    with open(i, 'rb') as handle:
        dc= pickle.load(handle)
    for i,j in dc.items():
        new_dct[i] = j[0]
        dc = {}
    with open(f'/cephyr/NOBACKUP/groups/snic2019-35-21/PPI/cls_embed/{name}', 'wb') as handle:
        pickle.dump(new_dct, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# not_mean_embedded_vectors_bert_bfd_combined_27.pickle
#  11%|█         | 1/9 [00:35<04:42, 35.28s/it]
# not_mean_embedded_vectors_bert_bfd_combined_23.pickle
#  22%|██▏       | 2/9 [03:18<12:52, 110.30s/it]
# not_mean_embedded_vectors_bert_bfd_combined_25.pickle
#  33%|███▎      | 3/9 [04:58<10:35, 105.97s/it]
# not_mean_embedded_vectors_bert_bfd_combined_20.pickle
#  44%|████▍     | 4/9 [07:03<09:26, 113.34s/it]
# not_mean_embedded_vectors_bert_bfd_combined_21.pickle
#  56%|█████▌    | 5/9 [09:13<07:57, 119.30s/it]
# not_mean_embedded_vectors_bert_bfd_combined_24.pickle
#  67%|██████▋   | 6/9 [11:05<05:50, 116.78s/it]
# not_mean_embedded_vectors_bert_bfd_combined_22.pickle
#  78%|███████▊  | 7/9 [13:04<03:55, 117.67s/it]
# not_mean_embedded_vectors_bert_bfd_combined_2.pickle
#  78%|███████▊  | 7/9 [13:39<03:54, 117.09s/it]
# ---------------------------------------------------------------------------
# ...

# %%
# !python main_extracting_embed_combine.py --number "0"
# Out:
# 27
# 21253

# %%
new_dct = {}
for i,j in dc.items():
    new_dct[i] = np.sum(j[1:],axis = 0
    break
# Out:
# Prot_1350000
# [ 0.07706545 -0.02301599  0.02537657 -0.05445766  0.06982252 -0.00570044
#   0.00977     0.09550729 -0.01767233 -0.02388189  0.0208157   0.06064619
#   0.06127261  0.07175427  0.06341022  0.03527501  0.05888918  0.07365881
#  -0.05404685 -0.02297637  0.00948454  0.06561249  0.00276048 -0.06893443
#   0.0205249  -0.05934171  0.00192858 -0.00596548  0.05914265 -0.04655157
#  -0.10448419 -0.08378825  0.00252453 -0.05442933 -0.03291542  0.07051133
#   0.02942538  0.00432501  0.02784895  0.046124    0.04254983 -0.00909959
#  -0.01704218  0.06073214  0.10477635  0.04183111  0.03377152  0.02724421
#   0.03005851  0.00099412 -0.0851328   0.01304526 -0.00488574  0.00503459
#  -0.07138368  0.00340404  0.03930265  0.04640819 -0.06874244  0.05884596
#  -0.05287767  0.14426993  0.03932783 -0.01642645  0.09508078  0.01768924
#   0.06633069  0.01125479  0.06586099  0.11651932 -0.04053155 -0.02117562
#  -0.02825231  0.09478381 -0.01147448  0.00754966 -0.00878623  0.01974551
# ...

# %%
with open(f'/mimer/NOBACKUP/groups/snic2022-6-127/PPI_prediction/pickle/not_mean_embedded_vectors_bert_bfd_combined_27.pickle', 'rb') as handle:
        dc= pickle.load(handle)

# %%
import numpy as np
new_dct = {}
for i,j in dc.items():
    print(i)
    print(j[0])
    break
# Out:
# Prot_1350000
# [ 0.05354536  0.0181879   0.08191657 ... -0.03603695 -0.09965403
#  -0.03603479]

# %%
dc['Prot_1350000'].shape
# Out:
# (377, 1024)

# %%
for i in tqdm(glob.glob("/mimer/NOBACKUP/groups/snic2022-6-127/PPI_prediction/pickle/not*18*")):
    name = i.split("/")[-1]
    new_dct = {}
    print(name)
# try:
    with open(i, 'rb') as handle:
        dc= pickle.load(handle)
    for i,j in dc.items():
        new_dct[i] = np.sum(j[1:],axis = 0)
    dc = {}
    with open(f'/cephyr/NOBACKUP/groups/snic2019-35-21/PPI/sum_pickle_not_mean/{name}', 'wb') as handle:
        pickle.dump(new_dct, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
            
#     except:
#         print("Error")
# Out:
# {'Prot_1200000': array([[ 0.05421106, -0.02958594,  0.06931055, ...,  0.0213291 ,
#          -0.00967056, -0.03361431],
#         [-0.01351368,  0.08832916,  0.07497805, ...,  0.17423885,
#          -0.00644627,  0.12947734],
#         [-0.15178908, -0.06520289,  0.04451934, ...,  0.09125556,
#          -0.05214868, -0.05079403],
#         ...,
#         [-0.19500813, -0.03474722,  0.06062601, ...,  0.09948725,
#          -0.09346094, -0.06940982],
#         [-0.16526547, -0.00279101,  0.18179354, ...,  0.07238291,
#          -0.1456345 , -0.00689707],
#         [ 0.05050896, -0.03536886,  0.06000081, ...,  0.02732492,
#          -0.01286366, -0.02425851]], dtype=float32),
#  'Prot_1200001': array([[ 0.07647501,  0.06947929,  0.15473664, ...,  0.02973906,
#          -0.06566802, -0.03849669],
#         [ 0.07284496,  0.10404961, -0.0048458 , ...,  0.11083367,
#          -0.10977872,  0.08232804],
#         [-0.06776664,  0.01178661, -0.00298721, ...,  0.0563678 ,
# ...
