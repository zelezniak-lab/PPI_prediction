# %%
import numpy as np
import pandas as pd
import Bio.SeqIO as SeqIO
from tqdm import tqdm
from collections import Counter
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/home/anwer/Desktop/PPI_prediction/Dataset_ppi/In/species:human.txt", sep='\t')

# %%
data
# Out:
#        uniprotkb:Q72547 uniprotkb:Q72547.1  \
# 0      uniprotkb:Q72547   uniprotkb:Q72547
# 1      uniprotkb:Q72547   uniprotkb:Q72547
# 2      uniprotkb:Q90VU7   uniprotkb:Q900A7
# 3      uniprotkb:Q7LYY4   uniprotkb:P17535
# 4      uniprotkb:Q7LYY4   uniprotkb:P17535
# ...                 ...                ...
# 70379  uniprotkb:P14404   uniprotkb:Q9NXW2
# 70380  uniprotkb:P14404   uniprotkb:Q86VM9
# 70381  uniprotkb:P14404   uniprotkb:O14925
# 70382  uniprotkb:P0CK48   uniprotkb:A6SZC0
# 70383  uniprotkb:D5H2E2   uniprotkb:Q1HVD3
#
#                   intact:EBI-7484755|intact:MINT-8208544  \
# 0                 intact:EBI-7484755|intact:MINT-8208544
# 1                 intact:EBI-7484755|intact:MINT-8208544
# 2                 intact:EBI-7460704|intact:MINT-5281653
# 3                 intact:EBI-7159363|intact:MINT-1174882
# 4                 intact:EBI-7159363|intact:MINT-1174882
# ...                                                  ...
# ...
